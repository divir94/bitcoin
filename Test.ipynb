# %%
import pickle

# %%
pickle.load(open('spreads.pickle'))
# Out:
# {'2017-06-21, 01:00 AM': {'orders': {'bitstamp': {'ask': u'2789.00',
#     'bid': u'2783.75'},
#    'gdax': {'ask': u'2780.01', 'bid': u'2780'}},
#   'spread': 3.75},
#  '2017-06-21, 01:00 PM': {'orders': {'bitstamp': {'ask': u'2721.55',
#     'bid': u'2717.25'},
#    'gdax': {'ask': u'2702.27', 'bid': u'2702.26'}},
#   'spread': 14.989999999999782},
#  '2017-06-21, 01:01 AM': {'orders': {'bitstamp': {'ask': u'2784.20',
#     'bid': u'2783.61'},
#    'gdax': {'ask': u'2780.01', 'bid': u'2780'}},
#   'spread': 3.6100000000001273},
#  '2017-06-21, 01:01 PM': {'orders': {'bitstamp': {'ask': u'2721.41',
#     'bid': u'2721.34'},
#    'gdax': {'ask': u'2702.01', 'bid': u'2702'}},
#   'spread': 19.340000000000146},
#  '2017-06-21, 01:02 AM': {'orders': {'bitstamp': {'ask': u'2787.60',
#     'bid': u'2785.01'},
#    'gdax': {'ask': u'2780.01', 'bid': u'2780'}},
#   'spread': 5.010000000000218},
#  '2017-06-21, 01:02 PM': {'orders': {'bitstamp': {'ask': u'2719.92',
#     'bid': u'2715.00'},
# ...
